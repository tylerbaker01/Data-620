# %% [markdown]
# # Week 2 Assignment
# ## Tyler Baker
#
# The goals of this assignment are:
# - find a dataset.
# - upload the data.
# - create a basic analysis. Must include the graph's diameter and one other metric of my choosing.
# - display the information.
# - create a short video explaining the data.

# %% [markdown]
# ### Setting up the Environment
#
# For this project. I want to use NetworkX, and matplotlib.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib notebook

# %% [markdown]
# ### The data
#
# The data I have chosen to use is of a karate club from the 70's. Zachery was able to understand why the club fractured from this data.

# %%
G = nx.karate_club_graph()
nx.draw(G, with_labels=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Basic Analysis
# #### Diameter
# The diameter is the longest shortest path. The shortest path is simply the shortest path one can take from some node A to reach some other node B. So the diameter is essentially just stating what what two nodes are the furtherest away from each other and exactly how far they are. I will use networkx's built in function to calculate.

# %%
nx.diameter(G)
# Out:
# 5

# %% [markdown]
# #### Cycles
# The cycles function returns all of the cycles within a graph. For example [8, 33, 31, 0] from a cycle. Meaning that if we start  with one of these numbers we can loop through the others to end at the node we started from.

# %%
nx.cycle_basis(G)
# Out:
# [[8, 33, 31, 0],
#  [13, 33, 31, 0],
#  [19, 33, 31, 0],
#  [28, 33, 31],
#  [32, 33, 31],
#  [1, 30, 33, 31, 0],
#  [8, 30, 33],
#  [32, 30, 33],
#  [23, 29, 33],
#  [26, 29, 33],
#  [32, 29, 33],
#  [2, 27, 33, 31, 0],
#  [23, 27, 33],
#  [24, 27, 33, 31],
#  [25, 23, 33, 31],
#  [32, 23, 33],
#  [32, 22, 33],
#  [32, 20, 33],
#  [32, 18, 33],
#  [32, 15, 33],
#  [32, 14, 33],
#  [2, 9, 33, 31, 0],
#  [2, 32, 31, 0],
#  [8, 32, 31, 0],
#  [2, 28, 31, 0],
#  [24, 25, 31],
#  [1, 21, 0],
#  [1, 19, 0],
#  [1, 17, 0],
#  [1, 13, 0],
#  [2, 13, 0],
#  [3, 13, 0],
#  [3, 12, 0],
#  [4, 10, 0],
#  [5, 10, 0],
#  [2, 8, 0],
#  [1, 7, 0],
#  [2, 7, 0],
#  [3, 7, 0],
#  [4, 6, 0],
#  [5, 6, 0],
#  [5, 16, 6],
#  [1, 3, 0],
#  [2, 3, 0],
#  [1, 2, 0]]

# %% [markdown]
# ### Centrality Measures
# We weren't asked to find centrality measures but I would like to practice a few of them anyways.
# #### Degree Centrality
# This is the measure of how many edges are connected to a node.

# %%
nx.degree_centrality(G)
# Out:
# {0: 0.48484848484848486,
#  1: 0.2727272727272727,
#  2: 0.30303030303030304,
#  3: 0.18181818181818182,
#  4: 0.09090909090909091,
#  5: 0.12121212121212122,
#  6: 0.12121212121212122,
#  7: 0.12121212121212122,
#  8: 0.15151515151515152,
#  9: 0.06060606060606061,
#  10: 0.09090909090909091,
#  11: 0.030303030303030304,
#  12: 0.06060606060606061,
#  13: 0.15151515151515152,
#  14: 0.06060606060606061,
#  15: 0.06060606060606061,
#  16: 0.06060606060606061,
#  17: 0.06060606060606061,
#  18: 0.06060606060606061,
#  19: 0.09090909090909091,
#  20: 0.06060606060606061,
#  21: 0.06060606060606061,
#  22: 0.06060606060606061,
#  23: 0.15151515151515152,
#  24: 0.09090909090909091,
#  25: 0.09090909090909091,
#  26: 0.06060606060606061,
#  27: 0.12121212121212122,
#  28: 0.09090909090909091,
#  29: 0.12121212121212122,
#  30: 0.12121212121212122,
#  31: 0.18181818181818182,
#  32: 0.36363636363636365,
#  33: 0.5151515151515151}

# %% [markdown]
# This shows that nodes 33 and 0 are the most and second most popular nodes. I am going to guess that these 2 nodes represent the senseis that fracture.

# %% [markdown]
# #### Closeness Centrality
# Closeness measures how close a node is to all other nodes in a graph.

# %%
nx.closeness_centrality(G)
# Out:
# {0: 0.5689655172413793,
#  1: 0.4852941176470588,
#  2: 0.559322033898305,
#  3: 0.4647887323943662,
#  4: 0.3793103448275862,
#  5: 0.38372093023255816,
#  6: 0.38372093023255816,
#  7: 0.44,
#  8: 0.515625,
#  9: 0.4342105263157895,
#  10: 0.3793103448275862,
#  11: 0.36666666666666664,
#  12: 0.3707865168539326,
#  13: 0.515625,
#  14: 0.3707865168539326,
#  15: 0.3707865168539326,
#  16: 0.28448275862068967,
#  17: 0.375,
#  18: 0.3707865168539326,
#  19: 0.5,
#  20: 0.3707865168539326,
#  21: 0.375,
#  22: 0.3707865168539326,
#  23: 0.39285714285714285,
#  24: 0.375,
#  25: 0.375,
#  26: 0.3626373626373626,
#  27: 0.4583333333333333,
#  28: 0.4520547945205479,
#  29: 0.38372093023255816,
#  30: 0.4583333333333333,
#  31: 0.5409836065573771,
#  32: 0.515625,
#  33: 0.55}

# %% [markdown]
# #### Betweenness Centrality
# If a node has a high betweenness, then we can say that the node often acts as a bridge for other nodes.

# %%
nx.betweenness_centrality(G)
# Out:
# {0: 0.43763528138528146,
#  1: 0.053936688311688304,
#  2: 0.14365680615680618,
#  3: 0.011909271284271283,
#  4: 0.0006313131313131313,
#  5: 0.02998737373737374,
#  6: 0.029987373737373736,
#  7: 0.0,
#  8: 0.05592682780182781,
#  9: 0.0008477633477633478,
#  10: 0.0006313131313131313,
#  11: 0.0,
#  12: 0.0,
#  13: 0.04586339586339586,
#  14: 0.0,
#  15: 0.0,
#  16: 0.0,
#  17: 0.0,
#  18: 0.0,
#  19: 0.03247504810004811,
#  20: 0.0,
#  21: 0.0,
#  22: 0.0,
#  23: 0.017613636363636363,
#  24: 0.0022095959595959595,
#  25: 0.0038404882154882154,
#  26: 0.0,
#  27: 0.02233345358345358,
#  28: 0.0017947330447330447,
#  29: 0.0029220779220779218,
#  30: 0.014411976911976909,
#  31: 0.13827561327561325,
#  32: 0.145247113997114,
#  33: 0.30407497594997596}

# %% [markdown]
# This again shows that node 0 and node 33 are the highest.

# %% [markdown]
# ### Final Thoughts
# I am pretty sure that nodes 0 and 33 are the two senseis that had a fallout which caused the dojo to split. I will guess that node 33 is the original sensei and that node 0 was a "right hand man". Node 0 was in charge of communicating information between students, while node 33 was the figure head.

# %% [markdown]
# #### Youtube Link
# https://youtu.be/jhNCFVhi4wo
